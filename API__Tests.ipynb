# %%
# Importing Data From Yahoo Finance

import pandas as pd
import yfinance as yf
from pandas.tseries.offsets import BMonthEnd

# Fetch the historical data for AAPL, at a specific frequancy (M)
ticker = '^VIX'
data = yf.download(ticker, start='1990-01-01', end='2022-07-21', interval='1mo')

# Extract the OHLC prices
ohlc = data[['Open', 'High', 'Low', 'Close', 'Volume']]

# Create a pandas DataFrame from the OHLC data
df = pd.DataFrame(ohlc)
df.index = pd.to_datetime(df.index)  # Convert index to datetime

df.index = pd.to_datetime(df.index) + BMonthEnd(0)  # Add BMonthEnd(0) to the index
df.index = df.index.strftime('%m/%d/%Y')

df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Volume
# Date
# 02/28/1990  24.870001  24.870001  19.709999  21.990000       0
# 03/30/1990  21.900000  22.740000  17.620001  19.730000       0
# 04/30/1990  22.840000  24.160000  17.730000  19.520000       0
# 05/31/1990  18.430000  20.139999  16.719999  17.370001       0
# 06/29/1990  17.090000  19.360001  14.720000  15.500000       0
# ...               ...        ...        ...        ...     ...
# 03/31/2022  29.450001  37.520000  18.670000  20.559999       0
# 04/29/2022  20.620001  34.340000  18.450001  33.400002       0
# 05/31/2022  33.349998  36.639999  24.940001  26.190001       0
# 06/30/2022  26.049999  35.049999  23.740000  28.709999       0
# 07/29/2022  29.530001  29.820000  21.209999  21.330000       0
#
# [390 rows x 5 columns]
